# %%
import pandas as pd

constituents_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/08bc72ca5fccf86ca4f3702f9db068a11a592509/data/constituents.csv'
cons_df = pd.read_csv(constituents_url)
objects_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/objects.csv'
objects_df = pd.read_csv(objects_url)
objects_constituents_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/objects_constituents.csv'
objects_cons_df = pd.read_csv(objects_constituents_url)
text_entries_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/objects_text_entries.csv'
text_entries_df = pd.read_csv(text_entries_url)
media_items_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/media_items.csv'
media_df = pd.read_csv(media_items_url)
media_relationships_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/media_relationships.csv'
media_relationships_df = pd.read_csv(media_relationships_url)
# Out:
# /var/folders/vt/5lpj5r5j0sg4g69qhz9_kqzc0000gn/T/ipykernel_19485/689904132.py:6: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   objects_df = pd.read_csv(objects_url)
# /var/folders/vt/5lpj5r5j0sg4g69qhz9_kqzc0000gn/T/ipykernel_19485/689904132.py:8: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   objects_cons_df = pd.read_csv(objects_constituents_url)

# %%
media_relationships_df.dtypes
media_relationships_df.isna().sum()
# Out:
# mediaid          0
# relatedid        0
# relatedentity    0
# dtype: int64

# %%
media_df.isna().sum()
media_df.dtypes
# Out:
# mediaid               int64
# mediatype            object
# title                object
# description          object
# duration            float64
# language             object
# thumbnailurl         object
# playurl              object
# downloadurl          object
# keywords             object
# tags                 object
# imageurl             object
# presentationdate     object
# releasedate          object
# lastmodified         object
# dtype: object

# %%
objects_df.isna().sum()
# Out:
# objectid                            0
# uuid                                0
# accessioned                         0
# accessionnum                        0
# locationid                     141720
# title                               0
# displaydate                     11524
# beginyear                          50
# endyear                            68
# visualbrowsertimespan              50
# medium                           1241
# dimensions                      21017
# inscription                     60826
# markings                       129078
# attributioninverted                 0
# attribution                         0
# provenancetext                  64958
# creditline                         25
# classification                      0
# subclassification              101617
# visualbrowserclassification         0
# parentid                       114107
# isvirtual                           0
# departmentabbr                      0
# portfolio                      141379
# series                         105364
# volume                         141818
# watermarks                     134252
# lastdetectedmodification            0
# wikidataid                      16580
# customprinturl                 143701
# dtype: int64

# %%
limit = len(objects_df) * 0.7
objects_df = objects_df.dropna(thresh=limit, axis=1)

# %%
target_cols = ['medium', 'dimensions', 'inscription', 'markings', 'provenancetext']

available_cols = [col for col in target_cols if col in objects_df.columns]

objects_df[available_cols] = objects_df[available_cols].fillna("Unknown")

# %%
print(objects_df.columns.tolist())
# Out:
# ['objectid', 'uuid', 'accessioned', 'accessionnum', 'title', 'displaydate', 'beginyear', 'endyear', 'visualbrowsertimespan', 'medium', 'dimensions', 'attributioninverted', 'attribution', 'creditline', 'classification', 'visualbrowserclassification', 'isvirtual', 'departmentabbr', 'lastdetectedmodification', 'wikidataid']

# %%
objects_df = objects_df.dropna(subset=['beginyear', 'endyear', 'creditline', 'visualbrowsertimespan'])

# %%
objects_df.isna().sum()
# Out:
# objectid                           0
# uuid                               0
# accessioned                        0
# accessionnum                       0
# title                              0
# displaydate                    11472
# beginyear                          0
# endyear                            0
# visualbrowsertimespan              0
# medium                             0
# dimensions                         0
# attributioninverted                0
# attribution                        0
# creditline                         0
# classification                     0
# visualbrowserclassification        0
# isvirtual                          0
# departmentabbr                     0
# lastdetectedmodification           0
# wikidataid                     16512
# dtype: int64

# %%
if 'displaydate' in objects_df.columns:
    objects_df['displaydate'] = objects_df['displaydate'].fillna(objects_df['beginyear'].astype(str))
    
if 'wikidataid' in objects_df.columns:
    objects_df['wikidataid'] = objects_df['wikidataid'].fillna('Not Linked')

# %%
objects_df.isna().sum()
# Out:
# objectid                       0
# uuid                           0
# accessioned                    0
# accessionnum                   0
# title                          0
# displaydate                    0
# beginyear                      0
# endyear                        0
# visualbrowsertimespan          0
# medium                         0
# dimensions                     0
# attributioninverted            0
# attribution                    0
# creditline                     0
# classification                 0
# visualbrowserclassification    0
# isvirtual                      0
# departmentabbr                 0
# lastdetectedmodification       0
# wikidataid                     0
# dtype: int64

# %%
objects_cons_df.dtypes
objects_cons_df.isna().sum()
# Out:
# objectid              0
# constituentid         0
# displayorder          0
# roletype              0
# role                  0
# prefix           831334
# suffix           781333
# displaydate      588720
# beginyear        694458
# endyear          695456
# country          611194
# zipcode          612747
# dtype: int64

# %%
objects_df.isna().sum()
# Out:
# objectid                       0
# uuid                           0
# accessioned                    0
# accessionnum                   0
# title                          0
# displaydate                    0
# beginyear                      0
# endyear                        0
# visualbrowsertimespan          0
# medium                         0
# dimensions                     0
# attributioninverted            0
# attribution                    0
# creditline                     0
# classification                 0
# visualbrowserclassification    0
# isvirtual                      0
# departmentabbr                 0
# lastdetectedmodification       0
# wikidataid                     0
# dtype: int64

# %% [markdown]
# Constituents, objects_constituents down

# %%
objects_cons_df.dtypes
objects_cons_df.isna().sum()
# Out:
# objectid              0
# constituentid         0
# displayorder          0
# roletype              0
# role                  0
# prefix           831334
# suffix           781333
# displaydate      588720
# beginyear        694458
# endyear          695456
# country          611194
# zipcode          612747
# dtype: int64

# %%
cons_df.dtypes
cons_df.isna().sum()
# Out:
# constituentid                   0
# uuid                            0
# ulanid                      19500
# preferreddisplayname            1
# forwarddisplayname              0
# lastname                     3178
# displaydate                  6035
# artistofngaobject               0
# beginyear                    8116
# endyear                     10187
# visualbrowsertimespan        8116
# nationality                  6652
# visualbrowsernationality        0
# constituenttype                 0
# wikidataid                  18672
# dtype: int64

# %%
import pandas as pd

constituents_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/08bc72ca5fccf86ca4f3702f9db068a11a592509/data/constituents.csv'
cons_df = pd.read_csv(constituents_url)
objects_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/objects.csv'
objects_df = pd.read_csv(objects_url)
objects_constituents_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/objects_constituents.csv'
objects_cons_df = pd.read_csv(objects_constituents_url)
text_entries_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/objects_text_entries.csv'
text_entries_df = pd.read_csv(text_entries_url)
media_items_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/media_items.csv'
media_df = pd.read_csv(media_items_url)
media_relationships_url = 'https://raw.githubusercontent.com/NationalGalleryOfArt/opendata/refs/heads/main/data/media_relationships.csv'
media_relationships_df = pd.read_csv(media_relationships_url)
# Out:
# /var/folders/w7/23_x_krd56dgz3l_g0tp_m0w0000gn/T/ipykernel_64250/689904132.py:6: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   objects_df = pd.read_csv(objects_url)
# /var/folders/w7/23_x_krd56dgz3l_g0tp_m0w0000gn/T/ipykernel_64250/689904132.py:8: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   objects_cons_df = pd.read_csv(objects_constituents_url)

# %% [markdown]
# ## Data Cleaning

# %%
media_relationships_df.dtypes
media_relationships_df.isna().sum()
# Out:
# mediaid          0
# relatedid        0
# relatedentity    0
# dtype: int64

# %%
media_df.isna().sum()
media_df.dtypes
# Out:
# mediaid               int64
# mediatype            object
# title                object
# description          object
# duration            float64
# language             object
# thumbnailurl         object
# playurl              object
# downloadurl          object
# keywords             object
# tags                 object
# imageurl             object
# presentationdate     object
# releasedate          object
# lastmodified         object
# dtype: object

# %%
objects_df.isna().sum()
# Out:
# objectid                            0
# uuid                                0
# accessioned                         0
# accessionnum                        0
# locationid                     141720
# title                               0
# displaydate                     11524
# beginyear                          50
# endyear                            68
# visualbrowsertimespan              50
# medium                           1241
# dimensions                      21017
# inscription                     60826
# markings                       129078
# attributioninverted                 0
# attribution                         0
# provenancetext                  64958
# creditline                         25
# classification                      0
# subclassification              101617
# visualbrowserclassification         0
# parentid                       114107
# isvirtual                           0
# departmentabbr                      0
# portfolio                      141379
# series                         105364
# volume                         141818
# watermarks                     134252
# lastdetectedmodification            0
# wikidataid                      16580
# customprinturl                 143701
# dtype: int64

# %%
limit = len(objects_df) * 0.7
objects_df = objects_df.dropna(thresh=limit, axis=1)

# %%
target_cols = ['medium', 'dimensions', 'inscription', 'markings', 'provenancetext']

available_cols = [col for col in target_cols if col in objects_df.columns]

objects_df[available_cols] = objects_df[available_cols].fillna("Unknown")

# %%
print(objects_df.columns.tolist())
# Out:
# ['objectid', 'uuid', 'accessioned', 'accessionnum', 'title', 'displaydate', 'beginyear', 'endyear', 'visualbrowsertimespan', 'medium', 'dimensions', 'attributioninverted', 'attribution', 'creditline', 'classification', 'visualbrowserclassification', 'isvirtual', 'departmentabbr', 'lastdetectedmodification', 'wikidataid']

# %%
objects_df = objects_df.dropna(subset=['beginyear', 'endyear', 'creditline', 'visualbrowsertimespan'])

# %%
objects_df.isna().sum()
# Out:
# objectid                           0
# uuid                               0
# accessioned                        0
# accessionnum                       0
# title                              0
# displaydate                    11472
# beginyear                          0
# endyear                            0
# visualbrowsertimespan              0
# medium                             0
# dimensions                         0
# attributioninverted                0
# attribution                        0
# creditline                         0
# classification                     0
# visualbrowserclassification        0
# isvirtual                          0
# departmentabbr                     0
# lastdetectedmodification           0
# wikidataid                     16512
# dtype: int64

# %%
if 'displaydate' in objects_df.columns:
    objects_df['displaydate'] = objects_df['displaydate'].fillna(objects_df['beginyear'].astype(str))
    
if 'wikidataid' in objects_df.columns:
    objects_df['wikidataid'] = objects_df['wikidataid'].fillna('Not Linked')

# %%
objects_df.isna().sum()
# Out:
# objectid                       0
# uuid                           0
# accessioned                    0
# accessionnum                   0
# title                          0
# displaydate                    0
# beginyear                      0
# endyear                        0
# visualbrowsertimespan          0
# medium                         0
# dimensions                     0
# attributioninverted            0
# attribution                    0
# creditline                     0
# classification                 0
# visualbrowserclassification    0
# isvirtual                      0
# departmentabbr                 0
# lastdetectedmodification       0
# wikidataid                     0
# dtype: int64

# %%
objects_cons_df.dtypes
objects_cons_df.isna().sum()
#objects_cons_df.roletype.unique()
#objects_cons_df
objects_cons_df['objectid'] = objects_cons_df['objectid'].replace(0, 'NaN')

# %%
objects_df.isna().sum()
# Out:
# objectid                       0
# uuid                           0
# accessioned                    0
# accessionnum                   0
# title                          0
# displaydate                    0
# beginyear                      0
# endyear                        0
# visualbrowsertimespan          0
# medium                         0
# dimensions                     0
# attributioninverted            0
# attribution                    0
# creditline                     0
# classification                 0
# visualbrowserclassification    0
# isvirtual                      0
# departmentabbr                 0
# lastdetectedmodification       0
# wikidataid                     0
# dtype: int64

# %% [markdown]
# Constituents, objects_constituents down

# %%
objects_cons_df.dtypes
objects_cons_df.isna().sum()
objects_cons_df
# Out:
#        objectid  constituentid  displayorder roletype            role prefix  \
# 0           NaN             12             4    owner   current owner    NaN
# 1           NaN            427             1    donor           donor    NaN
# 2           NaN            427             2    donor          source    NaN
# 3           NaN            427             3    owner  previous owner    NaN
# 4           NaN           1102             1    owner  previous owner    NaN
# ...         ...            ...           ...      ...             ...    ...
# 839057   233967             12             2    owner   current owner    NaN
# 839058   233967          27654             1    donor          source    NaN
# 839059   233967          27654             1    owner  previous owner    NaN
# 839060   233967          27654             2    donor           donor    NaN
# 839061   233967          44363             1   artist          artist    NaN
#
#                 suffix  displaydate  beginyear  endyear        country  \
# 0                  NaN       1937 -     1937.0      NaN  United States
# 1                  NaN          NaN        NaN      NaN            NaN
# 2                  NaN          NaN        NaN      NaN            NaN
# 3                  NaN  1936 - 1937     1936.0   1937.0            NaN
# 4       , New York, NY       - 1936        NaN   1936.0            NaN
# ...                ...          ...        ...      ...            ...
# 839057             NaN          NaN        NaN      NaN            NaN
# 839058             NaN          NaN        NaN      NaN            NaN
# 839059             NaN          NaN        NaN      NaN            NaN
# 839060             NaN          NaN        NaN      NaN            NaN
# 839061             NaN          NaN        NaN      NaN            NaN
#
#         zipcode
# 0       20565.0
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 839057      NaN
# 839058      NaN
# 839059      NaN
# 839060      NaN
# 839061      NaN
#
# [839062 rows x 12 columns]

# %%
cons_df.dtypes
cons_df.isna().sum()
cons_df
remove = ['anonymous artist', 'anonymous']
cons_df['preferreddisplayname'] = cons_df['preferreddisplayname'].str.lower().str.strip()
cons_df['preferreddisplayname'] = cons_df['preferreddisplayname'].replace(remove, 'Anonymous')
cons_df
cons_df['forwarddisplayname'] = cons_df['forwarddisplayname'].str.lower().str.strip()
cons_df['forwarddisplayname'] = cons_df['forwarddisplayname'].replace(remove, 'Anonymous')
cons_df
# Out:
#        constituentid                                  uuid       ulanid  \
# 0                  9  57edbe2d-6702-4d41-9190-2a2945bc2c89          NaN
# 1                 11  125c640d-e39b-4ae4-8455-f0b5e913c09e          NaN
# 2                 12  e4d45117-9800-4315-9184-916c53e64c8d  500115983.0
# 3                 13  7331a3f2-50fd-4838-b41d-f8013eb2456c          NaN
# 4                 14  6b4e3681-b09e-4cbd-9f3c-ff7830173c59          NaN
# ...              ...                                   ...          ...
# 27766          54663  7e507508-19be-46a5-ac77-dceb689fc6b4          NaN
# 27767          54692  cc016903-caeb-473c-821a-b27d5b254b8b          NaN
# 27768          54706  126a49b4-5184-4a31-864f-ae62f425b5c6          NaN
# 27769          54719  70c9d72b-9e65-4796-8090-4eb59da84357          NaN
# 27770          54759  42d329a1-81c5-427e-84ff-21bafca600a9          NaN
#
#           preferreddisplayname       forwarddisplayname          lastname  \
# 0                    Anonymous                Anonymous               NaN
# 1                baldung, hans             hans baldung           Baldung
# 2      national gallery of art  national gallery of art               NaN
# 3                    Anonymous                Anonymous  Anonymous Artist
# 4       evans, thomas m., mrs.     mrs. thomas m. evans             Evans
# ...                        ...                      ...               ...
# 27766  alex cooper auctioneers  alex cooper auctioneers               NaN
# 27767           prager, joanne            joanne prager            Prager
# 27768     craven allen gallery     craven allen gallery               NaN
# 27769         bullock, raymond          raymond bullock           Bullock
# 27770         odieuvre, michel          michel odieuvre          Odieuvre
#
#                  displaydate  artistofngaobject  beginyear  endyear  \
# 0                  Anonymous                  0        NaN      NaN
# 1                        NaN                  1        NaN      NaN
# 2                        NaN                  0        NaN      NaN
# 3                        NaN                  1        NaN      NaN
# 4      American, 1923 - 2013                  0     1923.0   2013.0
# ...                      ...                ...        ...      ...
# 27766           founded 1924                  0     1924.0      NaN
# 27767                    NaN                  0        NaN      NaN
# 27768                    NaN                  0        NaN      NaN
# 27769               American                  0        NaN      NaN
# 27770    French, 1687 - 1756                  1     1687.0   1756.0
#
#       visualbrowsertimespan nationality visualbrowsernationality  \
# 0                       NaN         NaN                    Other
# 1                       NaN         NaN                    Other
# 2                       NaN         NaN                    Other
# 3                       NaN     Unknown                    Other
# 4              1901 to 1925    American                 American
# ...                     ...         ...                      ...
# 27766          1901 to 1925         NaN                    Other
# 27767                   NaN         NaN                    Other
# 27768                   NaN         NaN                    Other
# 27769                   NaN    American                 American
# 27770          1651 to 1700      French                   French
#
#       constituenttype wikidataid
# 0           anonymous        NaN
# 1          individual        NaN
# 2           corporate    Q214867
# 3           anonymous   Q4233718
# 4          individual        NaN
# ...               ...        ...
# 27766       corporate        NaN
# 27767      individual        NaN
# 27768       corporate        NaN
# 27769      individual        NaN
# 27770      individual        NaN
#
# [27771 rows x 15 columns]

# %% [markdown]
# ## Creating Database

# %%
import duckdb
import pandas as pd
import os

con = duckdb.connect("Museum.db")
print("Connected to Museum.db")
# Out:
# Connected to Museum.db

# %%
print(objects_df.dtypes)
# Out:
# objectid                         int64
# uuid                            object
# accessioned                      int64
# accessionnum                    object
# title                           object
# displaydate                     object
# beginyear                      float64
# endyear                        float64
# visualbrowsertimespan           object
# medium                          object
# dimensions                      object
# attributioninverted             object
# attribution                     object
# creditline                      object
# classification                  object
# visualbrowserclassification     object
# isvirtual                        int64
# departmentabbr                  object
# lastdetectedmodification        object
# wikidataid                      object
# dtype: object

# %%
# with open("museum.sql", "w") as file:
#     file.write("""
#      CREATE OR REPLACE TABLE objects (
#         objectid INTEGER,
#         uuid TEXT,
#         accessioned INTEGER,
#         accessionnum TEXT,
#         title TEXT,
#         displaydate DATE,
#         beginyear FLOAT,
#         endyear FLOAT,
#         visualbrowsertimespan TEXT,
#         medium TEXT,
#         dimensions TEXT,
#         attributioninverted TEXT,
#         attribution TEXT,
#         creditline TEXT,
#         classification TEXT,
#         isvirtual INTEGER,
#         departmntabbr TEXT,
#         lastdetectmodification TEXT,
#         wikidataid TEXT,
#         merged_classification TEXT,
#         PRIMARY KEY (objectid)
#         );
               
#     CREATE OR REPLACE TABLE cons (
#         constituentid INTEGER,
#         uuid INTEGER,
#         ulanid FLOAT,
#         preferreddisplayname TEXT,
#         forwarddisplayname TEXT,
#         lastname TEXT,
#         displaydate TEXT,
#         artistofngaobject INT,
#         beginyear FLOAT,
#         endyear FLOAT,
#         visualbrowsertimespan TEXT,
#         nationality TEXT,
#         visualbrowsernationality TEXT,
#         constituenttype TEXT,
#         wikidataid TEXT,
#         PRIMARY KEY (constituentid),
#     );
    
#     CREATE OR REPLACE TABLE media (
#         mediaid	INTEGER,
#         mediatype TEXT,
#         title TEXT,
#         description TEXT,
#         duration FLOAT,
#         language TEXT,
#         thumbnailurl TEXT,
#         playurl TEXT,
#         downloadurl TEXT,
#         keywords TEXT,
#         tags TEXT,
#         imageurl TEXT,
#         presentationdate DATE,
#         releasedate DATE,
#         lastmodified DATE,
#         PRIMARY KEY (mediaid)
#     );
    
#     CREATE OR REPLACE TABLE media_relationships (
#         mediaid INTEGER,
#         relatedid INTEGER,
#         relatedentity TEXT,
#         PRIMARY KEY (mediaid, relatedid),
#         FOREIGN KEY (mediaid) REFERENCES media(mediaid),
#         FOREIGN KEY (relatedid) REFERENCES objects(objectid)
#     );
               
#     CREATE OR REPLACE TABLE text_entries (
#         objectid INTEGER,
#         text TEXT,
#         texttype TEXT,
#         year FLOAT,
#         FOREIGN KEY (objectid) REFERENCES objects(objectid),
#     );
    
#     CREATE OR REPLACE TABLE objects_cons (
#         objectid INTEGER,
#         constituentid INTEGER,
#         displayorder INTEGER,
#         roletype TEXT,
#         role TEXT,
#         prefix TEXT,
#         suffix TEXT,
#         displaydate TEXT,
#         beginyear FLOAT,
#         endyear FLOAT,
#         country TEXT,
#         zipcode TEXT,
#         PRIMARY KEY (objectid),
#         FOREIGN KEY (constituentid) REFERENCES cons(constituentid),
#     );
    
#     """)

# %%
con.sql("DROP TABLE IF EXISTS media_relationships")
con.sql("DROP TABLE IF EXISTS text_entries")
con.sql("DROP TABLE IF EXISTS objects_cons")
con.sql("DROP TABLE IF EXISTS objects")
con.sql("DROP TABLE IF EXISTS cons")
con.sql("DROP TABLE IF EXISTS media")

con.sql("""
CREATE OR REPLACE TABLE objects AS
SELECT * FROM objects_df
""")

con.sql("""
CREATE OR REPLACE TABLE cons AS
SELECT * FROM cons_df
""")

con.sql("""
CREATE OR REPLACE TABLE media AS
SELECT * FROM media_df
""")

con.sql("""
CREATE OR REPLACE TABLE media_relationships AS
SELECT * FROM media_relationships_df
""")

con.sql("""
CREATE OR REPLACE TABLE text_entries AS
SELECT * FROM text_entries_df
""")

con.sql("""
CREATE OR REPLACE TABLE objects_cons AS
SELECT * FROM objects_df
""")

# %%
con.sql("""SELECT * FROM media""")
# Out:
# ┌───────────────┬───────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────┬──────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────┬────────────────────────┬────────────────────────┐
# │    mediaid    │ mediatype │                                                           title                                                            │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ duration │ language │                                                  thumbnailurl                                                  │                                                 playurl                                                 │                                          downloadurl                                           │                                         keywords                                         │                                                                          tags                                                                           │                                                   imageurl                                                    │    presentationdate    │      releasedate       │      lastmodified      │
# │     int64     │  varchar  │                                                          varchar                                                           │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       varchar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │  double  │ varchar  │                                                    varchar                                                     │                                                 varchar                                                 │                                            varchar                                             │                                         varchar                                          │                                                                         varchar                                                                         │                                                    varchar                                                    │        varchar         │        varchar         │        varchar         │
# ├───────────────┼───────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────┼──────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────┼────────────────────────┼────────────────────────┤
# │           111 │ audio     │ John Wilmerding Symposium on American Art and Community Celebration 2021: Session I: An Evening Celebration of Alma Thomas │ <p>Virtual introduction by former First Lady Michelle Obama; poetry reading and discussion with Ross Gay; and virtual exhibition tour with Seth Feman and Jonathan Frederick Walz.<br>\r\n<br>\r\nRoss Gay, poet, gardener, professor, department of English, Indiana University Bloomington, founding board member, Bloomington Community Orchard, co-founder, The Tenderness Project, and Alma W. Thomas: Everything is Beautiful catalog contributor; with Seth Feman, deputy director for art and interpretation and curator of photography, Chrysler Museum of Art, and exhibition curator for Alma W. Thomas: Everything is Beautiful; and Jonathan Frederick Walz, director of curatorial affairs and curator of American art, Columbus Museum of Art, exhibition curator for Alma W. Thomas: Everything is Beautiful, and American University Feminist Art History Conference session presenter</p>\r\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │       ·  │ ·        │                                            ·                                                                   │                                               ·                                                         │  ·                                                                                             │  ·                                                                                       │             ·                                                                                                                                           │                                            ·                                                                  │           ·            │           ·            │           ·            │
# │ 6322561303112 │ video     │ Vermeer’s Secrets: Conservation Imaging Lab (1/4/2023)                                                                     │ <div style="box-sizing: border-box; font-family: -apple-system, &quot;system-ui&quot;, &quot;Segoe UI&quot;, system-ui, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Web&quot;, sans-serif; font-size: 14px; font-style: normal; font-variant-ligatures: normal; font-variant-caps: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px;">A virtual tour of the findings and analysis of Vermeer’s Secrets, led by Senior Imaging Scientist, John Delaney, and Imaging Scientist, Kate Dooley. Delany and Dooley conduct their research in the chemical imaging lab in the conservation division at the National Gallery of Art and did the macroscale imaging of the Vermeer paintings inspiring the exhibition, <i>Vermeer’s Secrets</i>.<br>\r\n</div>\r\n<p>&nbsp;</p>\r\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │     NULL │ en       │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/thumbnails/docent-vermeers-secret-01042023.jpg        │ https://players.brightcove.net/1191289016001/default_default/index.html?videoId=6322561303112           │ NULL                                                                                           │ NULL                                                                                     │ ngaweb:audio-video/docent                                                                                                                               │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/infoboxes/docent-vermeers-secret-01042023.jpg        │ 2023-01-04 00:00:00-05 │ 2023-01-04 00:00:00-05 │ 2023-03-14 15:19:05-04 │
# ...
# │ 6339481510112 │ video     │ The Circle Lecture, Sarah Greenough, Etched by Light: Photogravures from the Collection, 1840-1940 (10.18.23)              │ <p><span style="font-style: normal; font-variant-caps: normal; font-weight: 400; letter-spacing: normal; orphans: auto; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: auto; word-spacing: 0px; -webkit-text-size-adjust: auto; -webkit-text-stroke-width: 0px; text-decoration: none; font-size: 12pt; font-family: &quot;Times New Roman&quot;, serif; color: black;">Sarah Greenough, senior curator and head of the department of photographs, gives an overview of the exhibition.</span></p>\r\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │     NULL │ en       │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/thumbnails/circle-etched-by-light.jpg                 │ https://players.brightcove.net/1191289016001/default_default/index.html?videoId=6339481510112           │ NULL                                                                                           │ NULL                                                                                     │ ngaweb:audio-video/development                                                                                                                          │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/infoboxes/circle-etched-by-light.jpg                 │ 2023-10-18 00:00:00-04 │ 2023-10-18 00:00:00-04 │ 2023-10-20 09:31:11-04 │
# │ 6341066711112 │ video     │ The Circle Lecture, Philip Brookman, Dorothea Lange: Seeing People (11.09.23)                                              │ <p><span style="font-style: normal; font-variant-caps: normal; font-weight: 400; letter-spacing: normal; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: auto; word-spacing: 0px; -webkit-text-size-adjust: auto; -webkit-text-stroke-width: 0px; text-decoration: none; font-size: 12pt; font-family: &quot;Times New Roman&quot;, serif; color: black;">Philip Brookman, consulting curator in the department of photographs</span><span style="caret-color: rgb(0, 0, 0); color: rgb(0, 0, 0); font-style: normal; font-variant-caps: normal; font-weight: 400; letter-spacing: normal; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: auto; word-spacing: 0px; -webkit-text-size-adjust: auto; -webkit-text-stroke-width: 0px; text-decoration: none; font-size: 12pt; font-family: &quot;Times New Roman&quot;, serif;">, gives an overview of the exhibition.</span></p>\r\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │     NULL │ en       │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/thumbnails/circle-lange.jpg                           │ https://players.brightcove.net/1191289016001/default_default/index.html?videoId=6341066711112           │ NULL                                                                                           │ NULL                                                                                     │ ngaweb:audio-video/development                                                                                                                          │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/infoboxes/circle-lange.jpg                           │ 2023-11-09 00:00:00-05 │ 2023-11-09 00:00:00-05 │ 2023-11-14 11:50:45-05 │
# │ 6342474760112 │ video     │ Mark Rothko: A Conversation with Arne Glimcher, Kate Rothko Prizel, and Christopher Rothko (11.17.23)                      │ <p>Join us for a conversation about Mark Rothko’s life and work with three people who have contributed significantly to the public accessibility and understanding of his art: Rothko’s children, Kate Rothko Prizel and Christopher Rothko, and gallerist Arne Glimcher. Adam Greenhalgh, associate curator at the National Gallery and curator of Mark Rothko: Paintings on Paper, will moderate.<br>\r\n</p>\r\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │     NULL │ en       │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/thumbnails/circle-rothko.jpg                          │ https://players.brightcove.net/1191289016001/default_default/index.html?videoId=6342474760112           │ NULL                                                                                           │ NULL                                                                                     │ ngaweb:audio-video/development                                                                                                                          │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/infoboxes/circle-rothko.jpg                          │ 2023-11-17 00:00:00-05 │ 2023-11-17 00:00:00-05 │ 2024-01-02 08:37:17-05 │
# │ 6347331959112 │ video     │ The Circle Lecture, Shelley Langdale, The Anxious Eye: German Expressionism and its Legacy (2.9.2024)                      │ <p>Shelley R. Langdale, Curator and Head of Modern and Contemporary Prints and Drawings, gives an overview of the exhibition.<br>\r\n</p>\r\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │     NULL │ en       │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/thumbnails/circle-the-anxious-eye.jpg                 │ https://players.brightcove.net/1191289016001/default_default/index.html?videoId=6347331959112           │ NULL                                                                                           │ NULL                                                                                     │ ngaweb:audio-video/development                                                                                                                          │ https://www.nga.gov/content/dam/ngaweb/audio-video/video/infoboxes/circle-the-anxious-eye.jpg                 │ 2024-02-09 00:00:00-05 │ 2024-02-09 00:00:00-05 │ 2024-02-21 14:45:58-05 │
# └───────────────┴───────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────┴──────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────┴────────────────────────┴────────────────────────┘
#   2685 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                15 columns
